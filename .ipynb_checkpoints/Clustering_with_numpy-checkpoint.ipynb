# %% [markdown]
# Import the necessary packages

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %% [markdown]
# Import the dataset

# %%
data = pd.read_csv('xclara.csv')
print(data.shape)
data.head()
# Out:
# (3000, 2)
#           V1         V2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176
# 3  11.120670  14.406780
# 4  23.711550   2.557729

# %% [markdown]
# Plot the data

# %%
f1 = data['V1'].values
f2 = data['V2'].values
X = np.array(list(zip(f1, f2)))
plt.scatter(f1, f2, c='black', s=7)

# %% [markdown]
# Euclidean Distance Caculator

# %%
def dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

# %% [markdown]
# Define number of clusters and initialize the coordinates of the centroids
#
# ### Later, change the way the coordinates are defined

# %%
# Number of clusters
k = 3
# X coordinates of random centroids
C_x = np.random.randint(0, np.max(X)-20, size=k)
# Y coordinates of random centroids
C_y = np.random.randint(0, np.max(X)-20, size=k)
C = np.array(list(zip(C_x, C_y)), dtype=np.float32)
print(C)
# Out:
# [[  9.  26.]
#  [  7.  55.]
#  [ 55.  44.]]

# %%
plt.scatter(f1, f2, c='#050505', s=7)
plt.scatter(C_x, C_y, marker='*', s=200, c='r')

# %% [markdown]
# Initialize variables

# %%
# To store the value of centroids when it updates
C_old = np.zeros(C.shape)

# Cluster Labels(0, 1, 2)
clusters = np.zeros(len(X))

# Error func. - Distance between new centroids and old centroids
error = dist(C, C_old, None)

# %% [markdown]
# Minimize error to find the correct cluster centroids

# %%
# Loop will run till the error becomes zero
while error != 0:
    # Assigning each value to its closest cluster
    for i in range(len(X)):
        distances = dist(X[i], C)
        cluster = np.argmin(distances)
        clusters[i] = cluster
    # Storing the old centroid values
    C_old = deepcopy(C)
    # Finding the new centroids by taking the average value
    for i in range(k):
        points = [X[j] for j in range(len(X)) if clusters[j] == i]
        C[i] = np.mean(points, axis=0)
    error = dist(C, C_old, None)

print(C)
# Out:
# [[  9.47804546  10.68605232]
#  [ 40.68362808  59.71589279]
#  [ 69.92418671 -10.1196413 ]]

# %%
colors = ['r', 'g', 'b', 'y', 'c', 'm']
fig, ax = plt.subplots()

print("X: " + str(X))
print("clusters: " + str(clusters))

for i in range(k):
        points = np.array([X[j] for j in range(len(X)) if clusters[j] == i])
        ax.scatter(points[:, 0], points[:, 1], s=7, c=colors[i])
ax.scatter(C[:, 0], C[:, 1], marker='*', s=200, c='#050505')
# Out:
# X: [[  2.072345  -3.241693]
#  [ 17.93671   15.78481 ]
#  [  1.083576   7.319176]
#  ...,
#  [ 64.46532  -10.50136 ]
#  [ 90.72282  -12.25584 ]
#  [ 64.87976  -24.87731 ]]
# clusters: [ 0.  0.  0. ...,  2.  2.  2.]
